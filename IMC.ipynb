# %% [markdown]
# <a href="https://colab.research.google.com/github/Kenneth-Fernando-Armijos-Moreira/POO2-3/blob/main/IMC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Indice de Masa Corporal
# # Armijos Kenneth

# %%
#@title Texto de título predeterminado { run: "auto" }
Peso = 80 #@param {type:"number"}
Talla = 1 #@param {type:"integer"}
imc=Peso/(Talla*Talla)
print(imc)
# Out:
# 80.0
